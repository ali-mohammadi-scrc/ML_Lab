# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

input_shape = x_train.shape[1:]
N_classes = 10

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, N_classes)
y_test = tf.keras.utils.to_categorical(y_test, N_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
class ResnetLayer(tf.keras.Model):
  def __init__(self, 
               filters=16, 
               kernel_size=3, 
               strides=1, 
               activation='relu', 
               batch_normalization=True):
    super().__init__(name='')
    self.conv = Conv2D(filters=filters, 
                       kernel_size=kernel_size, 
                       strides=strides,
                       activation=activation,
                       padding='same',
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4))
    if batch_normalization:
      self.bn = BatchNormalization()
    else: 
      self.bn = None
    if activation is not None:
      self.ac = Activation(activation)
    else:
      self.ac = None

  def call(self, input_tensor, training=False):
    x = self.conv(input_tensor)
    if self.bn is not None:
      x = self.bn(x, training=training)
    if self.ac is not None:
      x = self.ac(x)
    return x

# %%
class ResnetIdentityBlock(tf.keras.Model):
  def __init__(self, 
               filters=16, 
               kernel_size=3, 
               strides=1, 
               activation='relu'):
    super().__init__(name='')
    self.rn_a = ResnetLayer(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            activation=activation)
    self.rn_b = ResnetLayer(filters=filters,
                            kernel_size=kernel_size,
                            activation=None)
    if strides != 1:
      self.skip = ResnetLayer(filters=filters,
                              kernel_size=1,
                              strides=strides,
                              activation=None,
                              batch_normalization=False)
    else:
      self.skip = lambda x: x
    if activation is not None:
      self.ac = Activation(activation)
    else:
      self.ac = None

  def call(self, input_tensor, training=False):
    x = self.rn_a(input_tensor, training=training)
    x = self.rn_b(x, training=training)
    x += self.skip(input_tensor)
    if self.ac is not None:
      x = self.ac(x)
    return x

# %%
def Resnet20(input_shape, N_classes): 
  return tf.keras.models.Sequential([Input(shape=input_shape), 
                                     ResnetLayer(), 
                                     ResnetIdentityBlock(), 
                                     ResnetIdentityBlock(),
                                     ResnetIdentityBlock(),
                                     ResnetIdentityBlock(filters=32, strides=2),
                                     ResnetIdentityBlock(filters=32),
                                     ResnetIdentityBlock(filters=32),
                                     ResnetIdentityBlock(filters=64, strides=2),
                                     ResnetIdentityBlock(filters=64),
                                     ResnetIdentityBlock(filters=64),
                                     AveragePooling2D(pool_size=8),
                                     Flatten(),
                                     Dense(N_classes, 
                                           activation='softmax', 
                                           kernel_initializer='he_normal')])

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Prepare model model saving directory.
save_dir = './drive/MyDrive/Resnet20Cifar10/History'
filepath = os.path.join (save_dir, 'epoch.{epoch:03d}.h5')

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=2,
                             save_best_only=False,
                             save_weights_only=True,)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
model = Resnet20(input_shape, N_classes)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.001
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet_layer_63 (ResnetLayer (None, 32, 32, 16)        512
# _________________________________________________________________
# resnet_identity_block_27 (Re (None, 32, 32, 16)        4768
# _________________________________________________________________
# resnet_identity_block_28 (Re (None, 32, 32, 16)        4768
# _________________________________________________________________
# resnet_identity_block_29 (Re (None, 32, 32, 16)        4768
# _________________________________________________________________
# resnet_identity_block_30 (Re (None, 16, 16, 32)        14688
# _________________________________________________________________
# resnet_identity_block_31 (Re (None, 16, 16, 32)        18752
# _________________________________________________________________
# resnet_identity_block_32 (Re (None, 16, 16, 32)        18752
# _________________________________________________________________
# resnet_identity_block_33 (Re (None, 8, 8, 64)          58048
# _________________________________________________________________
# resnet_identity_block_34 (Re (None, 8, 8, 64)          74368
# _________________________________________________________________
# resnet_identity_block_35 (Re (None, 8, 8, 64)          74368
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# _________________________________________________________________

# %%
History = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    validation_data=(x_test, y_test),
                    shuffle=True,
                    callbacks=callbacks)
# Out:
# Epoch 1/200
# Learning rate:  0.001
# 391/391 [==============================] - 38s 89ms/step - loss: 1.9530 - accuracy: 0.3562 - val_loss: 1.4923 - val_accuracy: 0.5124
#
# Epoch 00001: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 1.2468 - accuracy: 0.6082 - val_loss: 1.3098 - val_accuracy: 0.5887
#
# Epoch 00002: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 1.0289 - accuracy: 0.6857 - val_loss: 1.2610 - val_accuracy: 0.6175
#
# Epoch 00003: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.8920 - accuracy: 0.7363 - val_loss: 1.0903 - val_accuracy: 0.6778
#
# Epoch 00004: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.004.h5
# Epoch 5/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.7774 - accuracy: 0.7780 - val_loss: 1.1573 - val_accuracy: 0.6641
#
# Epoch 00005: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.005.h5
# Epoch 6/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.6929 - accuracy: 0.8129 - val_loss: 1.1352 - val_accuracy: 0.6673
#
# Epoch 00006: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.6298 - accuracy: 0.8338 - val_loss: 1.0942 - val_accuracy: 0.7041
#
# Epoch 00007: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.007.h5
# Epoch 8/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.5681 - accuracy: 0.8555 - val_loss: 1.1805 - val_accuracy: 0.6913
#
# Epoch 00008: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.008.h5
# Epoch 9/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.5042 - accuracy: 0.8791 - val_loss: 1.1537 - val_accuracy: 0.7090
#
# Epoch 00009: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.009.h5
# Epoch 10/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4690 - accuracy: 0.8919 - val_loss: 1.2710 - val_accuracy: 0.6924
#
# Epoch 00010: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.010.h5
# Epoch 11/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4270 - accuracy: 0.9094 - val_loss: 1.3832 - val_accuracy: 0.6643
#
# Epoch 00011: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.011.h5
# Epoch 12/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3998 - accuracy: 0.9189 - val_loss: 1.0717 - val_accuracy: 0.7378
#
# Epoch 00012: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.012.h5
# Epoch 13/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3797 - accuracy: 0.9270 - val_loss: 1.1294 - val_accuracy: 0.7204
#
# Epoch 00013: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.013.h5
# Epoch 14/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3567 - accuracy: 0.9338 - val_loss: 1.4256 - val_accuracy: 0.6817
#
# Epoch 00014: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3351 - accuracy: 0.9448 - val_loss: 1.7008 - val_accuracy: 0.6681
#
# Epoch 00015: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.015.h5
# Epoch 16/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3172 - accuracy: 0.9514 - val_loss: 1.8187 - val_accuracy: 0.6686
#
# Epoch 00016: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.016.h5
# Epoch 17/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3265 - accuracy: 0.9472 - val_loss: 1.4143 - val_accuracy: 0.7169
#
# Epoch 00017: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.017.h5
# Epoch 18/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3142 - accuracy: 0.9530 - val_loss: 1.6878 - val_accuracy: 0.6856
#
# Epoch 00018: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.018.h5
# Epoch 19/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.3147 - accuracy: 0.9549 - val_loss: 1.4441 - val_accuracy: 0.7061
#
# Epoch 00019: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.019.h5
# Epoch 20/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2935 - accuracy: 0.9636 - val_loss: 1.5198 - val_accuracy: 0.7157
#
# Epoch 00020: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.020.h5
# Epoch 21/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2951 - accuracy: 0.9624 - val_loss: 1.9934 - val_accuracy: 0.6484
#
# Epoch 00021: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.021.h5
# Epoch 22/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2866 - accuracy: 0.9667 - val_loss: 1.6889 - val_accuracy: 0.6752
#
# Epoch 00022: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.022.h5
# Epoch 23/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2971 - accuracy: 0.9613 - val_loss: 1.3973 - val_accuracy: 0.7319
#
# Epoch 00023: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.023.h5
# Epoch 24/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2852 - accuracy: 0.9649 - val_loss: 1.4355 - val_accuracy: 0.7272
#
# Epoch 00024: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.024.h5
# Epoch 25/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2894 - accuracy: 0.9651 - val_loss: 1.6908 - val_accuracy: 0.6934
#
# Epoch 00025: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.025.h5
# Epoch 26/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2797 - accuracy: 0.9690 - val_loss: 1.6524 - val_accuracy: 0.7279
#
# Epoch 00026: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.026.h5
# Epoch 27/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2992 - accuracy: 0.9629 - val_loss: 1.9506 - val_accuracy: 0.6614
#
# Epoch 00027: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.027.h5
# Epoch 28/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2843 - accuracy: 0.9698 - val_loss: 1.8188 - val_accuracy: 0.6868
#
# Epoch 00028: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.028.h5
# Epoch 29/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2780 - accuracy: 0.9713 - val_loss: 2.7174 - val_accuracy: 0.5882
#
# Epoch 00029: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.029.h5
# Epoch 30/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2993 - accuracy: 0.9638 - val_loss: 1.6814 - val_accuracy: 0.6951
#
# Epoch 00030: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.030.h5
# Epoch 31/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2865 - accuracy: 0.9680 - val_loss: 1.5572 - val_accuracy: 0.7230
#
# Epoch 00031: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.031.h5
# Epoch 32/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2876 - accuracy: 0.9684 - val_loss: 1.6369 - val_accuracy: 0.7126
#
# Epoch 00032: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.032.h5
# Epoch 33/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2898 - accuracy: 0.9682 - val_loss: 2.2125 - val_accuracy: 0.6512
#
# Epoch 00033: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.033.h5
# Epoch 34/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2865 - accuracy: 0.9685 - val_loss: 1.4996 - val_accuracy: 0.7216
#
# Epoch 00034: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.034.h5
# Epoch 35/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2784 - accuracy: 0.9731 - val_loss: 1.6138 - val_accuracy: 0.7266
#
# Epoch 00035: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.035.h5
# Epoch 36/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2824 - accuracy: 0.9720 - val_loss: 1.5676 - val_accuracy: 0.7289
#
# Epoch 00036: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.036.h5
# Epoch 37/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2784 - accuracy: 0.9722 - val_loss: 1.4982 - val_accuracy: 0.7182
#
# Epoch 00037: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.037.h5
# Epoch 38/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2732 - accuracy: 0.9755 - val_loss: 1.4721 - val_accuracy: 0.7330
#
# Epoch 00038: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.038.h5
# Epoch 39/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2793 - accuracy: 0.9728 - val_loss: 1.5925 - val_accuracy: 0.7327
#
# Epoch 00039: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.039.h5
# Epoch 40/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2700 - accuracy: 0.9764 - val_loss: 1.5192 - val_accuracy: 0.7408
#
# Epoch 00040: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.040.h5
# Epoch 41/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2852 - accuracy: 0.9715 - val_loss: 1.8068 - val_accuracy: 0.6891
#
# Epoch 00041: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.041.h5
# Epoch 42/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2843 - accuracy: 0.9707 - val_loss: 1.5624 - val_accuracy: 0.7338
#
# Epoch 00042: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.042.h5
# Epoch 43/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2666 - accuracy: 0.9787 - val_loss: 2.1036 - val_accuracy: 0.6810
#
# Epoch 00043: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.043.h5
# Epoch 44/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2693 - accuracy: 0.9762 - val_loss: 2.3057 - val_accuracy: 0.6733
#
# Epoch 00044: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.044.h5
# Epoch 45/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.3014 - accuracy: 0.9653 - val_loss: 1.7891 - val_accuracy: 0.6889
#
# Epoch 00045: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.045.h5
# Epoch 46/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2767 - accuracy: 0.9756 - val_loss: 2.2990 - val_accuracy: 0.6666
#
# Epoch 00046: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.046.h5
# Epoch 47/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2634 - accuracy: 0.9795 - val_loss: 1.6123 - val_accuracy: 0.7350
#
# Epoch 00047: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.047.h5
# Epoch 48/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2753 - accuracy: 0.9752 - val_loss: 1.8920 - val_accuracy: 0.7011
#
# Epoch 00048: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.048.h5
# Epoch 49/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2876 - accuracy: 0.9719 - val_loss: 1.5441 - val_accuracy: 0.7377
#
# Epoch 00049: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.049.h5
# Epoch 50/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2664 - accuracy: 0.9786 - val_loss: 2.5118 - val_accuracy: 0.6484
#
# Epoch 00050: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.050.h5
# Epoch 51/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2753 - accuracy: 0.9757 - val_loss: 1.7585 - val_accuracy: 0.7124
#
# Epoch 00051: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.051.h5
# Epoch 52/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2787 - accuracy: 0.9745 - val_loss: 1.7335 - val_accuracy: 0.7246
#
# Epoch 00052: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.052.h5
# Epoch 53/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2816 - accuracy: 0.9745 - val_loss: 1.5420 - val_accuracy: 0.7321
#
# Epoch 00053: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.053.h5
# Epoch 54/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2683 - accuracy: 0.9776 - val_loss: 1.7480 - val_accuracy: 0.7303
#
# Epoch 00054: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.054.h5
# Epoch 55/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2755 - accuracy: 0.9755 - val_loss: 1.3800 - val_accuracy: 0.7450
#
# Epoch 00055: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.055.h5
# Epoch 56/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2794 - accuracy: 0.9739 - val_loss: 1.7143 - val_accuracy: 0.7298
#
# Epoch 00056: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.056.h5
# Epoch 57/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2784 - accuracy: 0.9753 - val_loss: 2.1278 - val_accuracy: 0.7129
#
# Epoch 00057: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.057.h5
# Epoch 58/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2675 - accuracy: 0.9787 - val_loss: 1.5599 - val_accuracy: 0.7509
#
# Epoch 00058: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.058.h5
# Epoch 59/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2642 - accuracy: 0.9788 - val_loss: 1.7773 - val_accuracy: 0.7038
#
# Epoch 00059: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.059.h5
# Epoch 60/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2785 - accuracy: 0.9741 - val_loss: 1.5957 - val_accuracy: 0.7552
#
# Epoch 00060: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.060.h5
# Epoch 61/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2825 - accuracy: 0.9730 - val_loss: 1.4721 - val_accuracy: 0.7446
#
# Epoch 00061: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.061.h5
# Epoch 62/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2672 - accuracy: 0.9798 - val_loss: 1.7337 - val_accuracy: 0.7111
#
# Epoch 00062: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.062.h5
# Epoch 63/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2652 - accuracy: 0.9798 - val_loss: 1.5049 - val_accuracy: 0.7492
#
# Epoch 00063: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.063.h5
# Epoch 64/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2675 - accuracy: 0.9785 - val_loss: 1.6064 - val_accuracy: 0.7334
#
# Epoch 00064: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.064.h5
# Epoch 65/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2753 - accuracy: 0.9765 - val_loss: 2.0225 - val_accuracy: 0.7044
#
# Epoch 00065: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.065.h5
# Epoch 66/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.2785 - accuracy: 0.9749 - val_loss: 1.7959 - val_accuracy: 0.7209
#
# Epoch 00066: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.066.h5
# Epoch 67/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.2658 - accuracy: 0.9795 - val_loss: 1.4734 - val_accuracy: 0.7337
#
# Epoch 00067: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.067.h5
# Epoch 68/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2679 - accuracy: 0.9781 - val_loss: 2.2405 - val_accuracy: 0.6710
#
# Epoch 00068: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.068.h5
# Epoch 69/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2756 - accuracy: 0.9753 - val_loss: 1.6381 - val_accuracy: 0.7358
#
# Epoch 00069: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.069.h5
# Epoch 70/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2799 - accuracy: 0.9740 - val_loss: 1.8533 - val_accuracy: 0.7080
#
# Epoch 00070: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.070.h5
# Epoch 71/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.2635 - accuracy: 0.9804 - val_loss: 1.7013 - val_accuracy: 0.7367
#
# Epoch 00071: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.071.h5
# Epoch 72/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2635 - accuracy: 0.9787 - val_loss: 1.5396 - val_accuracy: 0.7511
#
# Epoch 00072: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.072.h5
# Epoch 73/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2819 - accuracy: 0.9732 - val_loss: 1.8963 - val_accuracy: 0.7091
#
# Epoch 00073: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.073.h5
# Epoch 74/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2580 - accuracy: 0.9818 - val_loss: 1.6460 - val_accuracy: 0.7290
#
# Epoch 00074: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.074.h5
# Epoch 75/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2701 - accuracy: 0.9781 - val_loss: 1.7468 - val_accuracy: 0.7181
#
# Epoch 00075: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.075.h5
# Epoch 76/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2673 - accuracy: 0.9781 - val_loss: 1.7063 - val_accuracy: 0.7350
#
# Epoch 00076: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.076.h5
# Epoch 77/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2614 - accuracy: 0.9805 - val_loss: 1.4997 - val_accuracy: 0.7410
#
# Epoch 00077: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.077.h5
# Epoch 78/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2761 - accuracy: 0.9749 - val_loss: 1.4461 - val_accuracy: 0.7539
#
# Epoch 00078: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.078.h5
# Epoch 79/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2587 - accuracy: 0.9818 - val_loss: 1.6907 - val_accuracy: 0.7459
#
# Epoch 00079: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.079.h5
# Epoch 80/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2575 - accuracy: 0.9809 - val_loss: 1.6923 - val_accuracy: 0.7437
#
# Epoch 00080: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.080.h5
# Epoch 81/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2622 - accuracy: 0.9792 - val_loss: 1.5990 - val_accuracy: 0.7335
#
# Epoch 00081: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.081.h5
# Epoch 82/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2398 - accuracy: 0.9879 - val_loss: 1.1826 - val_accuracy: 0.8005
#
# Epoch 00082: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2121 - accuracy: 0.9988 - val_loss: 1.1618 - val_accuracy: 0.8045
#
# Epoch 00083: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2076 - accuracy: 0.9995 - val_loss: 1.1734 - val_accuracy: 0.8051
#
# Epoch 00084: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.2047 - accuracy: 0.9997 - val_loss: 1.1829 - val_accuracy: 0.8062
#
# Epoch 00085: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.2015 - accuracy: 0.9999 - val_loss: 1.1854 - val_accuracy: 0.8061
#
# Epoch 00086: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1988 - accuracy: 0.9999 - val_loss: 1.2041 - val_accuracy: 0.8072
#
# Epoch 00087: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.087.h5
# Epoch 88/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1957 - accuracy: 0.9999 - val_loss: 1.1986 - val_accuracy: 0.8077
#
# Epoch 00088: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.088.h5
# Epoch 89/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1923 - accuracy: 1.0000 - val_loss: 1.2058 - val_accuracy: 0.8083
#
# Epoch 00089: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.089.h5
# Epoch 90/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1886 - accuracy: 1.0000 - val_loss: 1.2202 - val_accuracy: 0.8089
#
# Epoch 00090: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.090.h5
# Epoch 91/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1844 - accuracy: 1.0000 - val_loss: 1.2087 - val_accuracy: 0.8081
#
# Epoch 00091: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.091.h5
# Epoch 92/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1797 - accuracy: 1.0000 - val_loss: 1.2309 - val_accuracy: 0.8060
#
# Epoch 00092: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.092.h5
# Epoch 93/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1744 - accuracy: 1.0000 - val_loss: 1.2399 - val_accuracy: 0.8084
#
# Epoch 00093: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.093.h5
# Epoch 94/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1687 - accuracy: 1.0000 - val_loss: 1.2368 - val_accuracy: 0.8094
#
# Epoch 00094: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.094.h5
# Epoch 95/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1624 - accuracy: 1.0000 - val_loss: 1.2371 - val_accuracy: 0.8066
#
# Epoch 00095: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.095.h5
# Epoch 96/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1556 - accuracy: 1.0000 - val_loss: 1.2492 - val_accuracy: 0.8087
#
# Epoch 00096: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.096.h5
# Epoch 97/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1487 - accuracy: 0.9999 - val_loss: 1.2680 - val_accuracy: 0.8057
#
# Epoch 00097: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.097.h5
# Epoch 98/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1417 - accuracy: 0.9999 - val_loss: 1.3099 - val_accuracy: 0.8027
#
# Epoch 00098: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.098.h5
# Epoch 99/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1364 - accuracy: 0.9999 - val_loss: 1.3159 - val_accuracy: 0.8011
#
# Epoch 00099: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.099.h5
# Epoch 100/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1318 - accuracy: 0.9999 - val_loss: 1.3277 - val_accuracy: 0.8013
#
# Epoch 00100: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.100.h5
# Epoch 101/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1279 - accuracy: 0.9998 - val_loss: 1.3193 - val_accuracy: 0.8033
#
# Epoch 00101: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.101.h5
# Epoch 102/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1247 - accuracy: 0.9998 - val_loss: 1.3194 - val_accuracy: 0.8028
#
# Epoch 00102: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.102.h5
# Epoch 103/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1209 - accuracy: 0.9999 - val_loss: 1.3203 - val_accuracy: 0.8035
#
# Epoch 00103: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.103.h5
# Epoch 104/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1176 - accuracy: 1.0000 - val_loss: 1.3126 - val_accuracy: 0.8032
#
# Epoch 00104: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.104.h5
# Epoch 105/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1140 - accuracy: 1.0000 - val_loss: 1.4250 - val_accuracy: 0.7968
#
# Epoch 00105: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.105.h5
# Epoch 106/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1118 - accuracy: 0.9998 - val_loss: 1.3912 - val_accuracy: 0.7959
#
# Epoch 00106: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.106.h5
# Epoch 107/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1100 - accuracy: 0.9997 - val_loss: 1.3438 - val_accuracy: 0.7978
#
# Epoch 00107: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.107.h5
# Epoch 108/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.1071 - accuracy: 0.9999 - val_loss: 1.3321 - val_accuracy: 0.8002
#
# Epoch 00108: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.108.h5
# Epoch 109/200
# Learning rate:  0.0001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.1050 - accuracy: 0.9999 - val_loss: 1.3192 - val_accuracy: 0.8003
#
# Epoch 00109: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.109.h5
# Epoch 110/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1027 - accuracy: 1.0000 - val_loss: 1.3341 - val_accuracy: 0.8020
#
# Epoch 00110: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.110.h5
# Epoch 111/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.3735 - val_accuracy: 0.7987
#
# Epoch 00111: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.111.h5
# Epoch 112/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0997 - accuracy: 0.9995 - val_loss: 1.4133 - val_accuracy: 0.7942
#
# Epoch 00112: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.112.h5
# Epoch 113/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0976 - accuracy: 0.9997 - val_loss: 1.3944 - val_accuracy: 0.7999
#
# Epoch 00113: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.113.h5
# Epoch 114/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0955 - accuracy: 0.9999 - val_loss: 1.3354 - val_accuracy: 0.8002
#
# Epoch 00114: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.114.h5
# Epoch 115/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0938 - accuracy: 0.9999 - val_loss: 1.3434 - val_accuracy: 0.8021
#
# Epoch 00115: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.115.h5
# Epoch 116/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0919 - accuracy: 1.0000 - val_loss: 1.3122 - val_accuracy: 0.8077
#
# Epoch 00116: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.116.h5
# Epoch 117/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0898 - accuracy: 1.0000 - val_loss: 1.4331 - val_accuracy: 0.7986
#
# Epoch 00117: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.117.h5
# Epoch 118/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0894 - accuracy: 0.9997 - val_loss: 1.4521 - val_accuracy: 0.7866
#
# Epoch 00118: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.118.h5
# Epoch 119/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0894 - accuracy: 0.9994 - val_loss: 1.3776 - val_accuracy: 0.7985
#
# Epoch 00119: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.119.h5
# Epoch 120/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0870 - accuracy: 0.9998 - val_loss: 1.3482 - val_accuracy: 0.8005
#
# Epoch 00120: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.120.h5
# Epoch 121/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0855 - accuracy: 0.9999 - val_loss: 1.3753 - val_accuracy: 0.8036
#
# Epoch 00121: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.121.h5
# Epoch 122/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 88ms/step - loss: 0.0842 - accuracy: 1.0000 - val_loss: 1.3472 - val_accuracy: 0.8063
#
# Epoch 00122: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.122.h5
# Epoch 123/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 1.3449 - val_accuracy: 0.8057
#
# Epoch 00123: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.123.h5
# Epoch 124/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 1.3483 - val_accuracy: 0.8050
#
# Epoch 00124: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.124.h5
# Epoch 125/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0835 - accuracy: 1.0000 - val_loss: 1.3466 - val_accuracy: 0.8062
#
# Epoch 00125: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.125.h5
# Epoch 126/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 1.3460 - val_accuracy: 0.8063
#
# Epoch 00126: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.126.h5
# Epoch 127/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0830 - accuracy: 1.0000 - val_loss: 1.3470 - val_accuracy: 0.8063
#
# Epoch 00127: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.127.h5
# Epoch 128/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 1.3506 - val_accuracy: 0.8068
#
# Epoch 00128: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.128.h5
# Epoch 129/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 1.3469 - val_accuracy: 0.8068
#
# Epoch 00129: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.129.h5
# Epoch 130/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0820 - accuracy: 1.0000 - val_loss: 1.3436 - val_accuracy: 0.8063
#
# Epoch 00130: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.130.h5
# Epoch 131/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.3442 - val_accuracy: 0.8068
#
# Epoch 00131: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.131.h5
# Epoch 132/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 88ms/step - loss: 0.0811 - accuracy: 1.0000 - val_loss: 1.3462 - val_accuracy: 0.8079
#
# Epoch 00132: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.132.h5
# Epoch 133/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0806 - accuracy: 1.0000 - val_loss: 1.3503 - val_accuracy: 0.8062
#
# Epoch 00133: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.133.h5
# Epoch 134/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 1.3509 - val_accuracy: 0.8070
#
# Epoch 00134: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.134.h5
# Epoch 135/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 1.3585 - val_accuracy: 0.8067
#
# Epoch 00135: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.135.h5
# Epoch 136/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 1.3485 - val_accuracy: 0.8076
#
# Epoch 00136: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.136.h5
# Epoch 137/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0781 - accuracy: 1.0000 - val_loss: 1.3488 - val_accuracy: 0.8078
#
# Epoch 00137: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.137.h5
# Epoch 138/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 1.3514 - val_accuracy: 0.8071
#
# Epoch 00138: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.138.h5
# Epoch 139/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 1.3602 - val_accuracy: 0.8062
#
# Epoch 00139: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.139.h5
# Epoch 140/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 1.3575 - val_accuracy: 0.8069
#
# Epoch 00140: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.140.h5
# Epoch 141/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 1.3559 - val_accuracy: 0.8069
#
# Epoch 00141: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.141.h5
# Epoch 142/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 1.3601 - val_accuracy: 0.8050
#
# Epoch 00142: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.142.h5
# Epoch 143/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 1.3566 - val_accuracy: 0.8068
#
# Epoch 00143: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.143.h5
# Epoch 144/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 1.3582 - val_accuracy: 0.8067
#
# Epoch 00144: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.144.h5
# Epoch 145/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0721 - accuracy: 1.0000 - val_loss: 1.3592 - val_accuracy: 0.8066
#
# Epoch 00145: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.145.h5
# Epoch 146/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 1.3633 - val_accuracy: 0.8067
#
# Epoch 00146: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.146.h5
# Epoch 147/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 1.3661 - val_accuracy: 0.8054
#
# Epoch 00147: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.147.h5
# Epoch 148/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 1.3670 - val_accuracy: 0.8067
#
# Epoch 00148: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.148.h5
# Epoch 149/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 1.3579 - val_accuracy: 0.8071
#
# Epoch 00149: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.149.h5
# Epoch 150/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 1.3719 - val_accuracy: 0.8070
#
# Epoch 00150: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.150.h5
# Epoch 151/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 1.3698 - val_accuracy: 0.8072
#
# Epoch 00151: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.151.h5
# Epoch 152/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 1.3717 - val_accuracy: 0.8073
#
# Epoch 00152: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.152.h5
# Epoch 153/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 1.3743 - val_accuracy: 0.8050
#
# Epoch 00153: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.153.h5
# Epoch 154/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 1.3703 - val_accuracy: 0.8063
#
# Epoch 00154: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.154.h5
# Epoch 155/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.8045
#
# Epoch 00155: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.155.h5
# Epoch 156/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 1.3707 - val_accuracy: 0.8056
#
# Epoch 00156: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.156.h5
# Epoch 157/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0627 - accuracy: 1.0000 - val_loss: 1.3769 - val_accuracy: 0.8053
#
# Epoch 00157: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.157.h5
# Epoch 158/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 1.3738 - val_accuracy: 0.8075
#
# Epoch 00158: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.158.h5
# Epoch 159/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 1.3741 - val_accuracy: 0.8067
#
# Epoch 00159: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.159.h5
# Epoch 160/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 1.3805 - val_accuracy: 0.8074
#
# Epoch 00160: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.160.h5
# Epoch 161/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 1.3726 - val_accuracy: 0.8077
#
# Epoch 00161: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.161.h5
# Epoch 162/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 91ms/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 1.3801 - val_accuracy: 0.8071
#
# Epoch 00162: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.162.h5
# Epoch 163/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 91ms/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 1.3770 - val_accuracy: 0.8077
#
# Epoch 00163: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.163.h5
# Epoch 164/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 1.3785 - val_accuracy: 0.8072
#
# Epoch 00164: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.164.h5
# Epoch 165/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 1.3796 - val_accuracy: 0.8068
#
# Epoch 00165: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.165.h5
# Epoch 166/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 1.3802 - val_accuracy: 0.8069
#
# Epoch 00166: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.166.h5
# Epoch 167/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 1.3823 - val_accuracy: 0.8080
#
# Epoch 00167: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.167.h5
# Epoch 168/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 1.3803 - val_accuracy: 0.8079
#
# Epoch 00168: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.168.h5
# Epoch 169/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 1.3796 - val_accuracy: 0.8075
#
# Epoch 00169: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.169.h5
# Epoch 170/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0595 - accuracy: 1.0000 - val_loss: 1.3812 - val_accuracy: 0.8065
#
# Epoch 00170: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.170.h5
# Epoch 171/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0594 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.8077
#
# Epoch 00171: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.171.h5
# Epoch 172/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0594 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.8072
#
# Epoch 00172: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.172.h5
# Epoch 173/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 1.3800 - val_accuracy: 0.8075
#
# Epoch 00173: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.173.h5
# Epoch 174/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 1.3812 - val_accuracy: 0.8076
#
# Epoch 00174: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.174.h5
# Epoch 175/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 1.3804 - val_accuracy: 0.8071
#
# Epoch 00175: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.175.h5
# Epoch 176/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.3859 - val_accuracy: 0.8070
#
# Epoch 00176: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.176.h5
# Epoch 177/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 1.3821 - val_accuracy: 0.8073
#
# Epoch 00177: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.177.h5
# Epoch 178/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 1.3812 - val_accuracy: 0.8071
#
# Epoch 00178: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.178.h5
# Epoch 179/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 1.3830 - val_accuracy: 0.8069
#
# Epoch 00179: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.179.h5
# Epoch 180/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 1.3807 - val_accuracy: 0.8074
#
# Epoch 00180: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.180.h5
# Epoch 181/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 1.3800 - val_accuracy: 0.8075
#
# Epoch 00181: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.181.h5
# Epoch 182/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 1.3808 - val_accuracy: 0.8070
#
# Epoch 00182: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.182.h5
# Epoch 183/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 1.3823 - val_accuracy: 0.8068
#
# Epoch 00183: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.183.h5
# Epoch 184/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 1.3829 - val_accuracy: 0.8078
#
# Epoch 00184: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.184.h5
# Epoch 185/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 1.3828 - val_accuracy: 0.8071
#
# Epoch 00185: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.185.h5
# Epoch 186/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0585 - accuracy: 1.0000 - val_loss: 1.3816 - val_accuracy: 0.8072
#
# Epoch 00186: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.186.h5
# Epoch 187/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0585 - accuracy: 1.0000 - val_loss: 1.3826 - val_accuracy: 0.8070
#
# Epoch 00187: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.187.h5
# Epoch 188/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 1.3810 - val_accuracy: 0.8070
#
# Epoch 00188: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.188.h5
# Epoch 189/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 1.3841 - val_accuracy: 0.8068
#
# Epoch 00189: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.189.h5
# Epoch 190/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 1.3858 - val_accuracy: 0.8074
#
# Epoch 00190: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.190.h5
# Epoch 191/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 1.3847 - val_accuracy: 0.8070
#
# Epoch 00191: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.191.h5
# Epoch 192/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 1.3828 - val_accuracy: 0.8070
#
# Epoch 00192: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.192.h5
# Epoch 193/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 1.3863 - val_accuracy: 0.8071
#
# Epoch 00193: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.193.h5
# Epoch 194/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 91ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 1.3845 - val_accuracy: 0.8067
#
# Epoch 00194: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.194.h5
# Epoch 195/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 1.3821 - val_accuracy: 0.8071
#
# Epoch 00195: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.195.h5
# Epoch 196/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 89ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 1.3834 - val_accuracy: 0.8075
#
# Epoch 00196: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.196.h5
# Epoch 197/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 1.3838 - val_accuracy: 0.8067
#
# Epoch 00197: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.197.h5
# Epoch 198/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 1.3830 - val_accuracy: 0.8072
#
# Epoch 00198: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.198.h5
# Epoch 199/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 1.3835 - val_accuracy: 0.8068
#
# Epoch 00199: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.199.h5
# Epoch 200/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 1.3847 - val_accuracy: 0.8064
#
# Epoch 00200: saving model to ./drive/MyDrive/Resnet20Cifar10/History/epoch.200.h5
