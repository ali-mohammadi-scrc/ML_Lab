# %%
# %cd ..
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import os

from loss_landscape.random_direction import plot_loss_val
# Out:
# f:\ScRc\Desktop\Universitaet Bonn\4'th Sem\Lab ML\Code\ML_Lab

# %%
base_path = 'Results/Models'
random_dirs_params = 'random_trials_20_50'
model_names = os.listdir(base_path)

# %%
for model_name in model_names:
    print('**** ', model_name, ' ****')

    steps = np.load(os.path.join(base_path, model_name, random_dirs_params, 'steps.npy'), allow_pickle=True)
    evals = np.load(os.path.join(base_path, model_name, random_dirs_params, 'evals.npy'), allow_pickle=True)
    evals = evals[:, :, [2, 1]] # Acc - MSE
    # evals = evals[:, :, [0, 1]]
    evals_mean = np.mean(evals, 0)

    fig, ax_loss = plt.subplots()
    ax_acc = ax_loss.twinx()
    plt_axes=(ax_loss, ax_acc)

    plot_loss_val(steps=steps, trials_evals=evals, plt_axes=plt_axes)
    plot_loss_val(steps=steps, trials_evals=[evals_mean], plt_axes=plt_axes, plt_colors=('g', 'y'), linestyle='-')
    ax_loss.set_ylabel('loss', size="x-large")
    ax_acc.set_ylabel('accuracy', size="x-large")
    plt.show()
# Out:
# ****  gaussian_noise_bias_cat_60  ****
# ****  mislabeling_bias_30  ****
# ****  mislabeling_bias_60  ****
# ****  mislabeling_bias_80  ****
# ****  size_bias_cat_30  ****
# ****  size_bias_cat_60  ****
# ****  size_bias_cat_90  ****
# ****  size_bias_ship_60  ****
# ****  unbiased  ****

# %%
# %matplotlib widget
fig, ax_loss = plt.subplots()
ax_acc = ax_loss.twinx()
plt_axes=(ax_loss, ax_acc)
    
for model_name in model_names:
    steps = np.load(os.path.join(base_path, model_name, random_dirs_params, 'steps.npy'), allow_pickle=True)
    evals = np.load(os.path.join(base_path, model_name, random_dirs_params, 'evals.npy'), allow_pickle=True)
    evals = evals[:, :, [2, 1]] # Acc - MSE
    # evals = evals[:, :, [0, 1]]
    evals_mean = np.mean(evals, 0)

    # plot_loss_val(steps=steps, trials_evals=evals, plt_axes=plt_axes)
    plot_loss_val(steps=steps, trials_evals=[evals_mean], plt_axes=plt_axes, plt_colors=('', ''), linestyle='-')

ax_loss.set_ylabel('loss', size="x-large")
ax_acc.set_ylabel('accuracy', size="x-large")
ax_loss.set_ylim([0, 0.2])
ax_acc.set_ylim([0, 1])
ax_acc.set_visible(False)
ax_loss.legend(model_names)
plt.show()

# %%
random_dirs_params = 'random_trials_50_2d'

for model_name in model_names:
    print('**** ', model_name, ' ****')

    steps = np.load(os.path.join(base_path, model_name, random_dirs_params, 'steps.npy'), allow_pickle=True)
    evals = np.load(os.path.join(base_path, model_name, random_dirs_params, 'evals.npy'), allow_pickle=True)
    # evals = evals[:, :, [2, 1]] # Acc - MSE
    evals = evals[:, :, [0, 1]]


    X, Y = np.meshgrid(steps, steps)
    Z = evals[:, :, 0]
    Z = np.clip(Z, 0, 50)

    fig = plt.figure()
    plt.contour(X, Y, Z, cmap='summer')
    plt.show()
# Out:
# ****  gaussian_noise_bias_cat_60  ****
# ****  mislabeling_bias_30  ****
# ****  mislabeling_bias_60  ****
# ****  mislabeling_bias_80  ****
# ****  size_bias_cat_30  ****
# ****  size_bias_cat_60  ****
# ****  size_bias_cat_90  ****
# ****  size_bias_ship_60  ****
# ****  unbiased  ****

# %%
random_dirs_params = 'random_trials_50_2d'

for model_name in model_names:
    print('**** ', model_name, ' ****')

    steps = np.load(os.path.join(base_path, model_name, random_dirs_params, 'steps.npy'), allow_pickle=True)
    evals = np.load(os.path.join(base_path, model_name, random_dirs_params, 'evals.npy'), allow_pickle=True)
    # evals = evals[:, :, [2, 1]] # Acc - MSE
    evals = evals[:, :, [0, 1]]


    X, Y = np.meshgrid(steps, steps)
    Z = evals[:, :, 0]
    Z = np.clip(Z, 0, 50)

    fig = plt.figure()
    ax = Axes3D(fig)
    surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)
    fig.colorbar(surf, shrink=0.5, aspect=5)
    plt.show()
# Out:
# ****  gaussian_noise_bias_cat_60  ****
# ****  mislabeling_bias_30  ****
# ****  mislabeling_bias_60  ****
# ****  mislabeling_bias_80  ****
# ****  size_bias_cat_30  ****
# ****  size_bias_cat_60  ****
# ****  size_bias_cat_90  ****
# ****  size_bias_ship_60  ****
# ****  unbiased  ****
